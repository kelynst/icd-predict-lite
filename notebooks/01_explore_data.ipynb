# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("✅ Libraries imported successfully!")

# Quick test DataFrame
df = pd.DataFrame({
    "ICD_Code": ["A01", "B02", "C03"],
    "Description": ["Typhoid fever", "Zoster", "Malignant neoplasm of lip"]
})

print(df)

# Plot test
df["ICD_Code"].value_counts().plot(kind="bar")
plt.show()
# Out:
# ✅ Libraries imported successfully!
#   ICD_Code                Description
# 0      A01              Typhoid fever
# 1      B02                     Zoster
# 2      C03  Malignant neoplasm of lip

# %%
import torch
print("Torch version:", torch.__version__)
print("CUDA available?", torch.cuda.is_available())
# Out:
# Torch version: 2.8.0
# CUDA available? False
